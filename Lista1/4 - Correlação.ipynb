# %% [markdown]
# # 4 - Correlação
# **Direto ao ponto**: correlação é o coeficiente de interdependência entre duas ou mais variáveis.
#
# Em muitos casos, quando analisamos algumas variáveis, essa interdependência é muito clara. Exemplo:
# - Massa corporal e altura,
# - Consumo de combustível e distância percorrida,
# - Número de anúncios e produtos vendidos,
# - Tempo de estudo e desempenho na avaliação.
#
# Entretanto, algumas vezes essa correlação pode não ser muito clara.

# %% [markdown]
# ## Correlações positivas

# %% [markdown]
# Primeiro é gerada uma seed, depois são gerados 1000 números aleatórios entre 0 e 50. Cria uma correlação de média 0, com devio padrão 50 e 1000 como o tamanho da correlação. Os números gerados aleatoriamente são adicionados na correlação como ruído. Depois é retornado uma matrix com coeficientes de correlação entre dois vetores.

# %%
import numpy as np

np.random.seed(1)

# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Positive Correlation with some noise
y = x + np.random.normal(0, 10, 1000)

np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81543901],
#        [0.81543901, 1.        ]])

# %% [markdown]
# Plota a correlação de x e y.

# %%
# import matplotlib
import matplotlib.pyplot as plt

plt.scatter(x, y)

# %% [markdown]
# ## Correlações negativas

# %% [markdown]
# Faz, praticamente, a mesma coisa das células anteriores, mas com relação negativa.

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)

# Negative Correlation with some noise
y = 100 - x + np.random.normal(0, 5, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.94957116],
#        [-0.94957116,  1.        ]])

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Correlação fraca ou sem correlação

# %% [markdown]
# Calcula a correlação entre dois arrays gerados aleatoriamente.

# %%
x = np.random.randint(0, 50, 1000)
y = np.random.randint(0, 50, 1000)

np.corrcoef(x, y)
# Out:
# array([[ 1.        , -0.00554681],
#        [-0.00554681,  1.        ]])

# %%
plt.scatter(x, y)

# %% [markdown]
# ## Correlação é diferente de causalidade!

# %% [markdown]
# ![chart.png](attachment:chart.png)
